# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# # Problem Statement
#
# The Scholastic Aptitude Test (SAT) was created by the college board and its facing an increasing competition from its counterpart, the America College Testing (ACT).The ACT signed different contracts with different states to administer the Junior and Senior mandated testing for college entry. This has stationed the ACT’s competitiveness even stronger compared to the SAT. With the new format for the SAT released in March 2016 that have seen noticeable changes in both participation level and test score, there is even a deeper concern for the board to increase its attractiveness and relevance.
#
# As part of the team researching national trends in these testing from 2017 to 2018 with emphasis on states participation and test scores, my presentation is centered on providing recommendations based on the data available and my analysis of them purposely to inform the board on the best path to thread regarding our marketing and funding strategy.
# How can the SAT increase participation with data available? Where can we center our marketing and funding strategy?

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd

# %%
sat1 = pd.read_csv('../data/sat_2017.csv')
sat1
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
sat1.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# Datasets Used

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **To-Do:** *Fill out this cell with outside research or any additional background information that will support your analysis.*

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
lst = [4,5,7,4,2]

def mean(lst):
    total = 0
    for num in lst:
        total += int(num)
    return total/len(lst)

mean(lst)
# Out:
# 4.4

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
lst = [4,5,7,4,2]
def standarddev(lst):
    devlst = []
    for num in lst:
        dev = (num - mean(lst))**2
        devlst.append(dev)
    stdev = (sum(devlst)/len(lst))**0.5
    return stdev
standarddev(lst)
# Out:
# 1.624807680927192

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def percentage_to_dec(n):
    return float(n.strip('%'))/100 ## using strip(%)
percentage_to_dec('50')
# Out:
# 0.5

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
sat1
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
sat1.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat1.isnull().head(5)
# Out:
#    State  Participation  Evidence-Based Reading and Writing   Math  Total
# 0  False          False                               False  False  False
# 1  False          False                               False  False  False
# 2  False          False                               False  False  False
# 3  False          False                               False  False  False
# 4  False          False                               False  False  False

# %%
sat1.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat1.isnull().mean()
# Out:
# State                                 0.0
# Participation                         0.0
# Evidence-Based Reading and Writing    0.0
# Math                                  0.0
# Total                                 0.0
# dtype: float64

# %%
sat1.isnull().mean()/100
# Out:
# State                                 0.0
# Participation                         0.0
# Evidence-Based Reading and Writing    0.0
# Math                                  0.0
# Total                                 0.0
# dtype: float64

# %%
sat1.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat1.dropna().head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat1.shape
# Out:
# (51, 5)

# %%
sat1.dropna().shape
# Out:
# (51, 5)

# %%
sat1.dropna().isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat1.columns= sat1.columns.str.lower()
sat1.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
new_columv_list = [
    'states',
    'participations',
    'evw',
    'maths',
    'totals'
]
new_columv_list
# Out:
# ['states', 'participations', 'evw', 'maths', 'totals']

# %%
sat1['participation'].map(percentage_to_dec)
# Out:
# 0     0.05
# 1     0.38
# 2     0.30
# 3     0.03
# 4     0.53
# 5     0.11
# 6     1.00
# 7     1.00
# 8     1.00
# 9     0.83
# 10    0.61
# 11    0.55
# 12    0.93
# 13    0.09
# 14    0.63
# 15    0.02
# 16    0.04
# 17    0.04
# 18    0.04
# 19    0.95
# 20    0.69
# 21    0.76
# 22    1.00
# 23    0.03
# 24    0.02
# 25    0.03
# 26    0.10
# 27    0.03
# 28    0.26
# 29    0.96
# 30    0.70
# 31    0.11
# 32    0.67
# 33    0.49
# 34    0.02
# 35    0.12
# 36    0.07
# 37    0.43
# 38    0.65
# 39    0.71
# 40    0.50
# 41    0.03
# 42    0.05
# 43    0.62
# 44    0.03
# 45    0.60
# 46    0.65
# 47    0.64
# 48    0.14
# 49    0.03
# 50    0.03
# Name: participation, dtype: float64

# %%
sat1['participation'] = sat1['participation'].map(percentage_to_dec)

# %%
sat1.head()
# Out:
#         state  participation  evidence-based reading and writing  math  total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
sat1
# Out:
#                    state  participation  evidence-based reading and writing  \
# 0                Alabama           0.05                                 593
# 1                 Alaska           0.38                                 547
# 2                Arizona           0.30                                 563
# 3               Arkansas           0.03                                 614
# 4             California           0.53                                 531
# 5               Colorado           0.11                                 606
# 6            Connecticut           1.00                                 530
# 7               Delaware           1.00                                 503
# 8   District of Columbia           1.00                                 482
# 9                Florida           0.83                                 520
# 10               Georgia           0.61                                 535
# ...

# %%
sat2 = pd.read_csv('../data/sat_2018.csv')
sat2
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            6%                                 595
# 1                 Alaska           43%                                 562
# 2                Arizona           29%                                 577
# 3               Arkansas            5%                                 592
# 4             California           60%                                 540
# 5               Colorado          100%                                 519
# 6            Connecticut          100%                                 535
# 7               Delaware          100%                                 505
# 8   District of Columbia           92%                                 497
# 9                Florida           56%                                 550
# 10               Georgia           70%                                 542
# ...

# %%
sat2.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat2.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat2.isnull().head(5)
# Out:
#    State  Participation  Evidence-Based Reading and Writing   Math  Total
# 0  False          False                               False  False  False
# 1  False          False                               False  False  False
# 2  False          False                               False  False  False
# 3  False          False                               False  False  False
# 4  False          False                               False  False  False

# %%
sat2.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat2.isnull().mean()
# Out:
# State                                 0.0
# Participation                         0.0
# Evidence-Based Reading and Writing    0.0
# Math                                  0.0
# Total                                 0.0
# dtype: float64

# %%
sat2.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat2.dropna().head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat2.shape
# Out:
# (51, 5)

# %%
sat2.dropna().shape
# Out:
# (51, 5)

# %%
sat2.dropna().isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
sat2.columns= sat2.columns.str.lower()
sat2.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
new_columv_list2 = [
    'states',
    'participations',
    'evw',
    'maths',
    'totals'
]
new_columv_list2
# Out:
# ['states', 'participations', 'evw', 'maths', 'totals']

# %%
sat2['participation'].map(percentage_to_dec)
# Out:
# 0     0.06
# 1     0.43
# 2     0.29
# 3     0.05
# 4     0.60
# 5     1.00
# 6     1.00
# 7     1.00
# 8     0.92
# 9     0.56
# 10    0.70
# 11    0.56
# 12    1.00
# 13    0.99
# 14    0.63
# 15    0.03
# 16    0.04
# 17    0.04
# 18    0.04
# 19    0.99
# 20    0.76
# 21    0.80
# 22    1.00
# 23    0.04
# 24    0.03
# 25    0.04
# 26    0.10
# 27    0.03
# 28    0.23
# 29    0.96
# 30    0.82
# 31    0.16
# 32    0.79
# 33    0.52
# 34    0.02
# 35    0.08
# 36    0.18
# 37    0.48
# 38    0.70
# 39    0.97
# 40    0.55
# 41    0.03
# 42    0.06
# 43    0.66
# 44    0.04
# 45    0.64
# 46    0.68
# 47    0.69
# 48    0.28
# 49    0.03
# 50    0.03
# Name: participation, dtype: float64

# %%
sat2['participation'] = sat2['participation'].map(percentage_to_dec)

# %%
sat2.head()
# Out:
#         state  participation  evidence-based reading and writing  math  total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
act1 = pd.read_csv('../data/act_2017.csv')
act1
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
act1.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act1.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
act1.isnull().head(5)
# Out:
#    State  Participation  English   Math  Reading  Science  Composite
# 0  False          False    False  False    False    False      False
# 1  False          False    False  False    False    False      False
# 2  False          False    False  False    False    False      False
# 3  False          False    False  False    False    False      False
# 4  False          False    False  False    False    False      False

# %%
act1.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
act1.isnull().mean()
# Out:
# State            0.0
# Participation    0.0
# English          0.0
# Math             0.0
# Reading          0.0
# Science          0.0
# Composite        0.0
# dtype: float64

# %%
act1.dropna().head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act1.shape
# Out:
# (52, 7)

# %%
act1.dropna().shape
# Out:
# (52, 7)

# %%
act1.dropna().isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %%
act1.columns= act1.columns.str.lower()
act1.columns
# Out:
# Index(['state', 'participation', 'english', 'math', 'reading', 'science',
#        'composite'],
#       dtype='object')

# %%
new_columv_act1 = [
    'states',
    'participations',
    'reading',
    'maths',
    'totals',
    'science',
    'composite'
]
new_columv_act1
# Out:
# ['states',
#  'participations',
#  'reading',
#  'maths',
#  'totals',
#  'science',
#  'composite']

# %%
act1['participation'].map(percentage_to_dec)
# Out:
# 0     0.60
# 1     1.00
# 2     0.65
# 3     0.62
# 4     1.00
# 5     0.31
# 6     1.00
# 7     0.31
# 8     0.18
# 9     0.32
# 10    0.73
# 11    0.55
# 12    0.90
# 13    0.38
# 14    0.93
# 15    0.35
# 16    0.67
# 17    0.73
# 18    1.00
# 19    1.00
# 20    0.08
# 21    0.28
# 22    0.29
# 23    0.29
# 24    1.00
# 25    1.00
# 26    1.00
# 27    1.00
# 28    0.84
# 29    1.00
# 30    0.18
# 31    0.34
# 32    0.66
# 33    0.31
# 34    1.00
# 35    0.98
# 36    0.75
# 37    1.00
# 38    0.40
# 39    0.23
# 40    0.21
# 41    1.00
# 42    0.80
# 43    1.00
# 44    0.45
# 45    1.00
# 46    0.29
# 47    0.29
# 48    0.29
# 49    0.69
# 50    1.00
# 51    1.00
# Name: participation, dtype: float64

# %%
act1['participation'] = act1['participation'].map(percentage_to_dec)

# %%
act1
# Out:
#                    state  participation  english  math  reading  science  \
# 0               National           0.60     20.3  20.7     21.4     21.0
# 1                Alabama           1.00     18.9  18.4     19.7     19.4
# 2                 Alaska           0.65     18.7  19.8     20.4     19.9
# 3                Arizona           0.62     18.6  19.8     20.1     19.8
# 4               Arkansas           1.00     18.9  19.0     19.7     19.5
# 5             California           0.31     22.5  22.7     23.1     22.2
# 6               Colorado           1.00     20.1  20.3     21.2     20.9
# 7            Connecticut           0.31     25.5  24.6     25.6     24.6
# 8               Delaware           0.18     24.1  23.4     24.8     23.6
# 9   District of Columbia           0.32     24.4  23.5     24.9     23.5
# 10               Florida           0.73     19.0  19.4     21.0     19.4
# 11               Georgia           0.55     21.0  20.9     22.0     21.3
# ...

# %%
act1['composite'] = [ item.replace('x', '') for item in    act1['composite']]

# %%
act1
# Out:
#                    state  participation  english  math  reading  science  \
# 0               National           0.60     20.3  20.7     21.4     21.0
# 1                Alabama           1.00     18.9  18.4     19.7     19.4
# 2                 Alaska           0.65     18.7  19.8     20.4     19.9
# 3                Arizona           0.62     18.6  19.8     20.1     19.8
# 4               Arkansas           1.00     18.9  19.0     19.7     19.5
# 5             California           0.31     22.5  22.7     23.1     22.2
# 6               Colorado           1.00     20.1  20.3     21.2     20.9
# 7            Connecticut           0.31     25.5  24.6     25.6     24.6
# 8               Delaware           0.18     24.1  23.4     24.8     23.6
# 9   District of Columbia           0.32     24.4  23.5     24.9     23.5
# 10               Florida           0.73     19.0  19.4     21.0     19.4
# 11               Georgia           0.55     21.0  20.9     22.0     21.3
# ...

# %%
act1.head()
# Out:
#       state  participation  english  math  reading  science composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
act2 = pd.read_csv('../data/act_2018.csv')
act2
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
act2.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act2.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act2.isnull().head(5)
# Out:
#    State  Participation  Composite
# 0  False          False      False
# 1  False          False      False
# 2  False          False      False
# 3  False          False      False
# 4  False          False      False

# %%
act2.isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
act2.isnull().mean()
# Out:
# State            0.0
# Participation    0.0
# Composite        0.0
# dtype: float64

# %%
act2 = act2.drop(19)

# %%
act2
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
act2.dropna().head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
act2.shape
# Out:
# (51, 3)

# %%
act2.dropna().shape
# Out:
# (51, 3)

# %%
act2.dropna().isnull().sum()
# Out:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
act2.columns= act2.columns.str.lower()
act2.columns
# Out:
# Index(['state', 'participation', 'composite'], dtype='object')

# %%
new_columv_act1 = [
    'states',
    'participations',
    'total'
]
new_columv_act1
# Out:
# ['states', 'participations', 'total']

# %%
act2['participation'].map(percentage_to_dec)
# Out:
# 0     1.00
# 1     0.33
# 2     0.66
# 3     1.00
# 4     0.27
# 5     0.30
# 6     0.26
# 7     0.17
# 8     0.32
# 9     0.66
# 10    0.53
# 11    0.89
# 12    0.36
# 13    0.43
# 14    0.32
# 15    0.68
# 16    0.71
# 17    1.00
# 18    1.00
# 20    0.07
# 21    0.31
# 22    0.25
# 23    0.22
# 24    0.99
# 25    1.00
# 26    1.00
# 27    1.00
# 28    1.00
# 29    1.00
# 30    0.16
# 31    0.31
# 32    0.67
# 33    0.27
# 34    1.00
# 35    0.98
# 36    1.00
# 37    1.00
# 38    0.42
# 39    0.20
# 40    0.15
# 41    1.00
# 42    0.77
# 43    1.00
# 44    0.45
# 45    1.00
# 46    0.24
# 47    0.24
# 48    0.24
# 49    0.65
# 50    1.00
# 51    1.00
# Name: participation, dtype: float64

# %%
act2['participation'] = act2['participation'].map(percentage_to_dec)

# %%
act2.head()
# Out:
#         state  participation  composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Code:

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **To-Do:** *Edit the table below to create your own data dictionary for the datasets you chose.*
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|
#                         blog_collegevine              SAT Score              int            SAT     2017 SAT Scores by State
#                         blog.prepscholar              SAT Score              int            SAT     2018 SAT Scores by state
#                         prepscholar.com               ACT Score              int            ACT     2017 ACT Scores by State
#                         prepscholar.com               ACT Score              int            ACT     2018 ACT Scores by State

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
sat1.describe()
# Out:
#        participation  evidence-based reading and writing        math  \
# count      51.000000                           51.000000   51.000000
# mean        0.398039                          569.117647  547.627451
# std         0.352766                           45.666901   84.909119
# min         0.020000                          482.000000   52.000000
# 25%         0.040000                          533.500000  522.000000
# 50%         0.380000                          559.000000  548.000000
# 75%         0.660000                          613.000000  599.000000
# max         1.000000                          644.000000  651.000000
#
#              total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %%
output_std_sat1 = {'participation': standarddev(sat1['participation']),
       'evidence-based reading and writing': standarddev(sat1['evidence-based reading and writing']),
       'math': standarddev(sat1['math']),
       'total': standarddev(sat1['total'])
        
      }
output_std_sat1
# Out:
# {'participation': 0.4734481723029228,
#  'evidence-based reading and writing': 45.21697020437866,
#  'math': 84.07255521608297,
#  'total': 91.58351056778743}

# %%
output_std_sat2 = {'participation': standarddev(sat2['participation']),
       'evidence-based reading and writing': standarddev(sat2['evidence-based reading and writing']),
       'math': standarddev(sat2['math']),
       'total': standarddev(sat2['total']), 
       
    
    
    
}
output_std_sat2
# Out:
# {'participation': 0.515443579661167,
#  'evidence-based reading and writing': 47.03460978357609,
#  'math': 47.30194550378352,
#  'total': 93.22742384464433}

# %%
output_std_act1 = {'participation': standarddev(act1['participation']),
       'english': standarddev(act1['english']),
       'math': standarddev(act1['math']),
       'reading': standarddev(act1['reading']),
       'science': standarddev(act1['science'])
       
    
    
}
output_std_act1
# Out:
# {'participation': 0.45250126679347996,
#  'english': 2.3473389188611007,
#  'math': 1.9986496920961356,
#  'reading': 2.0729127949871167,
#  'science': 3.157776631498477}

# %%
output_std_act2 = {'participation': standarddev(act2['participation'])
                  
}
output_std_act2
# Out:
# {'participation': 0.440672391763706}

# %%
#Code:
sat1

# %%
sat1.describe()
# Out:
#        participation  evidence-based reading and writing        math  \
# count      51.000000                           51.000000   51.000000
# mean        0.398039                          569.117647  547.627451
# std         0.352766                           45.666901   84.909119
# min         0.020000                          482.000000   52.000000
# 25%         0.040000                          533.500000  522.000000
# 50%         0.380000                          559.000000  548.000000
# 75%         0.660000                          613.000000  599.000000
# max         1.000000                          644.000000  651.000000
#
#              total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %%
sat2.head()
# Out:
#         state  participation  evidence-based reading and writing  math  total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
sat2.describe()
# Out:
#        participation  evidence-based reading and writing        math  \
# count      51.000000                           51.000000   51.000000
# mean        0.457451                          563.686275  556.235294
# std         0.373143                           47.502627   47.772623
# min         0.020000                          480.000000  480.000000
# 25%         0.045000                          534.500000  522.500000
# 50%         0.520000                          552.000000  544.000000
# 75%         0.775000                          610.500000  593.500000
# max         1.000000                          643.000000  655.000000
#
#              total
# count    51.000000
# mean   1120.019608
# std      94.155083
# min     977.000000
# 25%    1057.500000
# 50%    1098.000000
# 75%    1204.000000
# max    1298.000000

# %%
act1.head()
# Out:
#       state  participation  english  math  reading  science composite
# 0  National           0.60     20.3  20.7     21.4     21.0      21.0
# 1   Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           0.65     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           0.62     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas           1.00     18.9  19.0     19.7     19.5      19.4

# %%
act1.describe()
# Out:
#        participation    english       math    reading    science
# count      52.000000  52.000000  52.000000  52.000000  52.000000
# mean        0.651538  20.919231  21.173077  22.001923  21.040385
# std         0.318325   2.332132   1.963602   2.048672   3.151113
# min         0.080000  16.300000  18.000000  18.100000   2.300000
# 25%         0.310000  19.000000  19.400000  20.475000  19.900000
# 50%         0.680000  20.550000  20.900000  21.700000  21.150000
# 75%         1.000000  23.300000  23.100000  24.125000  22.525000
# max         1.000000  25.500000  25.300000  26.000000  24.900000

# %%
act2.head()
# Out:
#         state  participation  composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %%
act2.describe()
# Out:
#        participation  composite
# count      51.000000  51.000000
# mean        0.617255  21.496078
# std         0.340371   2.111583
# min         0.070000  17.700000
# 25%         0.285000  19.950000
# 50%         0.660000  21.300000
# 75%         1.000000  23.650000
# max         1.000000  25.600000

# %% [markdown]
# Which states have the highest and lowest participation rates for the 2017 and 2018 on SAT and ACT?
#
# It appears that Iowa,Mississippi and north Dakota has the lowest participation rate with each having two percent in SAT 2017
#
# Compare to states like Conneticut,Delaware and District of Columbia scoring highest of Hundred percent participation
# rate.
# In 2018 for SAT score,North Dakota maintained a two percent participation rate as the lowest while states like Conneticut,Delaware
# remained top with 100 percent participation rate,colorado and Michigan also joined the group recording 100 percent participation rate.
#
# ACT participation rate for 2017 and 2018
# In 2017,there was an overwhelming participation compare to the SAT.The lowest stands at Eight percent and that was recorded in the state
# of Maine. highest participation sits at hundred percent recorded in states like Alabama, Arkansas,Colorado, Kentucky,Louisiana,Minnesota,Missouri,Mississippi,Montana
# ,Nevada,Oklahoma,South Carolina,Tennessee,Utah,Wiscosin and Wyoming.
# In 2018, the ACT recorded lowest in the state of Maine with a drop to seven percent.Again, states like Alabama, Arkansas, Kentucky,Louisiana,Montana,Missouri,Mississippi,
# Nebraska,Nevada,North Carolina,Ohio,Oklahoma,South Carolina,Tennessee,Utah,Wiscosin and Wyoming.

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
sat1
# Out:
#                    state  participation  evidence-based reading and writing  \
# 0                Alabama           0.05                                 593
# 1                 Alaska           0.38                                 547
# 2                Arizona           0.30                                 563
# 3               Arkansas           0.03                                 614
# 4             California           0.53                                 531
# 5               Colorado           0.11                                 606
# 6            Connecticut           1.00                                 530
# 7               Delaware           1.00                                 503
# 8   District of Columbia           1.00                                 482
# 9                Florida           0.83                                 520
# 10               Georgia           0.61                                 535
# ...

# %%
sat1.corr()[['participation']]
# Out:
#                                     participation
# participation                            1.000000
# evidence-based reading and writing      -0.874326
# math                                    -0.566558
# total                                   -0.867540

# %%
corr = sat1.corr()
sns.heatmap(corr);

# %% [markdown]
# This diagram was used to set the independent or target variable(participation).It was used to find out  how all of the other variables affect paricipation rate in SAT 2017. Looking at the blue heatmap, the focus should be on the dark and light areas. Dark purple represents a positive correlation, while light Tan is a negative correlation.

# %%
corr = sat2.corr()
sns.heatmap(corr);

# %% [markdown]
# This diagram was used to set the independent or target variable(participation).It was used to find out how all of the other variables affect paricipation rate in SAT 2018. Looking at the blue heatmap, the focus should be on the dark and light areas. Dark purple represents a positive correlation, while light Tan is a negative correlation.

# %%
corr = act1.corr()
sns.heatmap(corr);

# %% [markdown]
# This diagram was used to set out the independent or target variable(participation).It was used to find out how all of the other variables affect paricipation rate in ACT 2017. Looking at the blue heatmap, the focus should be on the dark and light areas. Dark purple represents a positive correlation, while light Tan is a negative correlation.

# %%
corr = act2.corr()
sns.heatmap(corr);

# %% [markdown]
# This diagram was used to set the independent or target variable(participation).It was used to find out  how all of the other variable (composite) affect paricipation rate in ACT 2018. Looking at the blue heatmap, the focus should be on the dark and light areas. Dark purple represents a positive correlation, while light Tan is a negative correlation.

# %%
sat1.corr()[['participation']].sort_values(by = 'participation', ascending = False)
# Out:
#                                     participation
# participation                            1.000000
# math                                    -0.566558
# total                                   -0.867540
# evidence-based reading and writing      -0.874326

# %%
sns.heatmap(sat1.corr()[['participation']].sort_values(by = 'participation', ascending = False),
            annot = True, vmin = -1, vmax = 1);

# %% [markdown]
# This diagram was used to set the independent or target variable(participation).It was used to find out  how all of the other variables affect paricipation rate in SAT 2017. Looking at the blue heatmap, the focus should be on the dark and light areas. Dark purple represents a positive correlation, while light Tan is a negative correlation.But in this diagram, the dark side shown negative correlation showing not so much relationship existed between participation and other variables.Participation and other variables move in an opposite direction

# %%
sat2.corr()[['participation']].sort_values(by = 'participation', ascending = False)
# Out:
#                                     participation
# participation                            1.000000
# evidence-based reading and writing      -0.762055
# total                                   -0.785926
# math                                    -0.791338

# %%
sns.heatmap(sat2.corr()[['participation']].sort_values(by = 'participation', ascending = False),
            annot = True, vmin = -1, vmax = 1);

# %% [markdown]
# This diagram was used to set the independent or target variable(participation).It was used to find out  how all of the other variables affect paricipation rate in SAT 2018. Looking at the blue heatmap, the focus should be on the dark and light areas. Dark purple represents a positive correlation, while light Tan is a negative correlation.But in this diagram, the dark side shown negative correlation showing not so much relationship existed between participation and other variables.Participation and other variables move in an opposite direction

# %%
sns.heatmap(act1.corr()[['participation']].sort_values(by = 'participation', ascending = False),
            annot = True, vmin = -1, vmax = 1);

# %% [markdown]
# This diagram was used to set the independent or target variable(participation).It was used to find out  how all of the other variables affect paricipation rate in ACT 2017. Looking at the blue heatmap, the focus should be on the dark and light areas. Dark purple represents a positive correlation, while light Tan is a negative correlation.But in this diagram, the dark side shown negative correlation showing not so much relationship existed between participation and other variables.Participation and other variables move in an opposite direction.

# %%
sns.heatmap(act2.corr()[['participation']].sort_values(by = 'participation', ascending = False),
            annot = True, vmin = -1, vmax = 1);

# %% [markdown]
# This diagram was used to set the independent or target variable(participation).It was used to find out  how all of the other variables affect paricipation rate in ACT 2018. Looking at the blue heatmap, the focus should be on the dark and light areas. Dark purple represents a positive correlation, while light Tan is a negative correlation.But in this diagram, the dark side shown negative correlation showing not so much relationship existed between participation and other variables.Participation and other variables move in an opposite direction

# %%
## Mr noah's code
corr = sat1.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize = (12,12))

sns.heatmap(corr, cmap = 'coolwarm', annot = True, square = True, mask = mask, vmin = -1, vmax = 1);

# %% [markdown]
# In the diagram above,each variable is listed on both axis, and their relationships with other variables are displayed using color. As the color becomes darker in either direction (red or blue) that means that those variables are more highly correlated and should not be paired together in the same model. In this case,emphasis is on variables that are highly correlated with paricipation for SAT 2017.

# %%
## Mr noah's code
corr = sat2.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize = (12,12))

sns.heatmap(corr, cmap = 'coolwarm', annot = True, square = True, mask = mask, vmin = -1, vmax = 1);

# %% [markdown]
# In the diagram above,each variable is listed on both axis, and their relationships with other variables are displayed using color. As the color becomes darker in either direction (red or blue) that means that those variables are more highly correlated and should not be paired together in the same model. In this case,emphasis is on variables that are highly correlated with paricipation for SAT 2018.

# %%
## Mr noah's code
corr = act1.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize = (12,12))

sns.heatmap(corr, cmap = 'coolwarm', annot = True, square = True, mask = mask, vmin = -1, vmax = 1);

# %% [markdown]
# In the diagram above,each variable is listed on both axis, and their relationships with other variables are displayed using color. As the color becomes darker in either direction (red or blue) that means that those variables are more highly correlated and should not be paired together in the same model. In this case,emphasis is on variables that are highly correlated with paricipation for ACT 2017.

# %%
## Mr noah's code
corr = act2.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

plt.figure(figsize = (12,12))

sns.heatmap(corr, cmap = 'coolwarm', annot = True, square = True, mask = mask, vmin = -1, vmax = 1);

# %% [markdown]
# In the diagram above,each variable is listed on both axis, and their relationships with other variables are displayed using color. As the color becomes darker in either direction (red or blue) that means that those variables are more highly correlated and should not be paired together in the same model. In this case,the consideration is only on composite score and participation for ACT 2018.But it looks both are in opposite direction with a correlation of -.86

# %%
plt.figure(figsize = (12, 5))

plt.hist(sat1['participation'], color = 'teal') 

plt.title('SAT Participation rating by State in 2017');""
# Out:
# ''

# %% [markdown]
# This is a unimodal data set, with the mode closer to the left of the graph and smaller than either the mean or the median.
# This shape indicates that there are a number of data points, perhaps outliers, that are greater than the mode.

# %%
plt.figure(figsize = (12, 5))

plt.hist(act2['participation'], color = 'teal') 

plt.title('SAT Participation rating by State in 2018');""
# Out:
# ''

# %% [markdown]
# Here, there is outlier to the right but with almost no participation in the middle indicates
# having two separated classes or intervals equally representing the maximum frequency of the distribution.

# %%
plt.figure(figsize = (12, 5))

plt.hist(act1['participation'], color = 'teal') 

plt.title('ACT Participation rating by State in 2017');""
# Out:
# ''

# %% [markdown]
# Here, there is outlier to the right but with almost no participation in the middle indicates
# having two separated classes or intervals equally representing the maximum frequency of the distribution.

# %%
plt.figure(figsize = (12, 5))

plt.hist(act2['participation'], color = 'teal') 

plt.title('ACT Participation rating by State in 2017');""
# Out:
# ''

# %% [markdown]
# Here, there is outlier to the right but with almost no participation in the middle indicates
# having two separated classes or intervals equally representing the maximum frequency of the distribution.

# %%
sat1.head()
# Out:
#         state  participation  evidence-based reading and writing  math  total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
sat1['participation'].describe()
# Out:
# count    51.000000
# mean      0.398039
# std       0.352766
# min       0.020000
# 25%       0.040000
# 50%       0.380000
# 75%       0.660000
# max       1.000000
# Name: participation, dtype: float64

# %%
sns.boxplot(x = sat1['participation']);
# plt.xticks(range(35, 30, 2));

# %% [markdown]
# This figure above is is left-skewed indicating that many states recorded a high number of fewer participation rate.

# %%
sat2['participation'].describe()
# Out:
# count    51.000000
# mean      0.457451
# std       0.373143
# min       0.020000
# 25%       0.045000
# 50%       0.520000
# 75%       0.775000
# max       1.000000
# Name: participation, dtype: float64

# %%
sns.boxplot(x = sat2['participation']);
# plt.xticks(range(35, 30, 2));

# %% [markdown]
# This figure above is is left-skewed indicating that many states recorded a high number of fewer participation rate.

# %%
act1['participation'].describe()
# Out:
# count    52.000000
# mean      0.651538
# std       0.318325
# min       0.080000
# 25%       0.310000
# 50%       0.680000
# 75%       1.000000
# max       1.000000
# Name: participation, dtype: float64

# %%
act1['composite'] = [ item.replace('x', '') for item in    act1['composite']]

# %%
sns.boxplot(x = act1['participation']);
# plt.xticks(range(35, 30, 2));

# %% [markdown]
# This figure above is left-skewed indicating that many states recorded a high number of fewer participation rate.

# %%
act2['participation'].describe()
# Out:
# count    51.000000
# mean      0.617255
# std       0.340371
# min       0.070000
# 25%       0.285000
# 50%       0.660000
# 75%       1.000000
# max       1.000000
# Name: participation, dtype: float64

# %%
sns.boxplot(x = act2['composite']);
# plt.xticks(range(35, 30, 2));

# %% [markdown]
# This figure above is is right-skewed indicating that many states scored higher participation rate.The ACT picked momentum and recorded a huge participation rate above median.

# %%
plt.figure(figsize = (12, 5))

plt.scatter(sat1['participation'],
            sat1['total'])

# Create a descriptive title
plt.title('State-by-State-SAT participation Rating and Total score,2017')
# Add axis labels
plt.xlabel('participation')
plt.ylabel('total');

# %% [markdown]
# In 2017, there is a very weak correlation between participation and total score as shown in the scatter plot above.

# %%
plt.figure(figsize = (12, 5))

plt.scatter(sat2['participation'],
            sat2['total'])

#  descriptive title
plt.title('State-by-State-SAT participation Rating and Total score,2018')
## axis labels
plt.xlabel('participation')
plt.ylabel('total');

# %% [markdown]
# A negatively weak correlation exist in participation rating for SAT and total score 2017

# %% [markdown]
# A negatively weak correlation exist in participation rating for SAT and total score 2018

# %%
plt.figure(figsize = (20, 10))

plt.scatter(act1['participation'],
            act1['composite'])

# Create a descriptive title
plt.title('ACT participation Rating and Total score by State,2017', fontsize = 15)
# Add axis labels
plt.xlabel('participation', fontsize = 15)
plt.ylabel('composite', fontsize = 15);

# %% [markdown]
# There is no correlation as shown in this diagram.

# %%
plt.figure(figsize = (12, 5))

plt.scatter(act2['participation'],
            act2['composite'])

# Create a descriptive title
plt.title('ACT participation Rating and Composite score by State,2018', fontsize = 15)
# Add axis labels
plt.xlabel('participation', fontsize = 15)
plt.ylabel('composite', fontsize = 15);

# %% [markdown]
# There is a negatively weak correlation between participation rating  and composite score in 2018 for ACT test.

# %%
plt.figure(figsize = (20, 10))

plt.barh(sat1['state'][::-1],
         sat1['participation'][::-1])

# Create a descriptive title
plt.title('SAT Participation Rating by States in USA,2017', fontsize = 15)
# Add axis labels
plt.xlabel('Participation Rating', fontsize = 15);

# %%
plt.figure(figsize = (20, 10))

plt.barh(sat2['state'][::-1],
         sat2['participation'][::-1])

plt.title('SAT Participation Rating by States in USA,2018', fontsize = 20)

plt.xlabel('Participation Rating', fontsize = 20);

# %%
plt.figure(figsize = (20, 10))

plt.barh(act1['state'][::-1],
         act1['participation'][::-1])

plt.title('ACT Participation Rating by States in USA,2017', fontsize = 15)

plt.xlabel('Participation Rating', fontsize = 15);

# %%
plt.figure(figsize = (30, 20))

plt.barh(act2['state'][::-1],
         act2['participation'][::-1])

plt.title('ACT Participation Rating by States in USA,2018', fontsize = 15)

plt.xlabel('Participation Rating', fontsize = 15)
plt.yticks(fontsize = 15);

# %% [markdown]
# The above histograms represents SAT and ACT participation rating across the states in the United States of America(USA)
# for 2017 and 2018 respectively.There is a clear indication that participation in ACT by states is higher than participation by states in SAT.

# %% [markdown]
# # Data Analysis Report
#
# The data bases of SAT and ACT for 2017 and 2018 was extracted.The data was cleaned of unwanted rows,column as well as ensuring no data was missing. A quantitative analysis was carried out to understand the behaviour of the data.A summary statistic was done to measure the mean, standard deviation as well as minimum and maximum analysis.Different figures was constructed to visualize the outcome of every calculation carried out.The heatman was used to show correlations and the histogram drawn to determine frequency distribution of all the data sets.A scatter plot was also used to observe and show relationships between different numeric variables.The boxplot was also constructed to identify mean values, the dispersion of the data set, and signs of skewness.And most importantly to this research was the bar charts which helped in a wink to compare and track changes between the SAT and ACT with respect to participation over time.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# The SAT has seen a very strong competition from its counterpart, the ACT from 2017 through 2018 that has resulted in low participation rate. A thorough analysis to unravel issues that has posed danger to the participation level of the SAT college test is imperative.
#
# The percentage of participation by individual state in ACT is higher than that of SAT in most states. The average rate of particiaption for SAT in 2017 snd 2018 is 39 percent and 45 percentage respectively. Whereas average participation rate for the ACT for 2017 and 2918 is 65 percent and 61 percent respectively. This shows that on avaerage, the SAT gets 42 percentage participate rate from potential college students compare to the ACT with an average of 63 percentage.
#
# Also, there was a total number of eleven states scoring below 5 percent participation in SAT for the two years investigated whereas during same period for ACT, no state scored less than five percent. The lowest was seven percent. According to Census Bureau, the state of Mississippi, compared to other states and national median, have the lowest scores in terms of household income between 2017 and 2018. Results from this research also reveal Mississippi having the lowest participation rate for the same period.
#
# According to Chatmeter, "Want to stand out from your competitors? Do better than them". The SAT Board should study the initiatives enshrined in the contracts ACT implemented with different states that yielded such a huge success in order to be competitive. The SAT Board should run an initiative that will see states with very low household income benefit to increase participation rate and cover the inequality gap. For instance, states like Iowa, Mississippi and North Dakota, which repeatedly appear under four percent participation rate for the two years investigated, should be key areas to channel any marketing strategy.
#
# References
#
# 1) https://www.census.gov/library/stories/2019/09/us-median-household-income-up-in-2018-from-2017.html
#
# 2) https://www.chatmeter.com/blog/stand-out-competitors/
#
# 3) https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows
#
# 4) https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)

# %% [markdown]
# **To-Do:** *Edit this cell with your conclusions and recommendations.*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
